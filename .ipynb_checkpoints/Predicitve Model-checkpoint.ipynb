# %% [markdown]
# # Predictive Model

# %%
'''
File Name: Term Records
Contents of Files:
- Study 36404 -
Data Files Description
The data file contains one record for each separate term in prison. An individual person may have more than one record, but all will be assigned the same Abt_Inmate_ID value.
File Dimensions:
• No. of Cases: 10,907,333 • No. of Variables: 18
• Record Length: 54
• Records per Case: 1
• Overall No. of Records: 10,907,333
'''

import pandas as pd

df = pd.read_stata('ICPSR_36404-V2/ICPSR_36404/DS0001/36404-0001-Data.dta')
print(df.head())
# Out:
#          ABT_INMATE_ID   SEX  \
# 0  A012015000000091071  Male
# 1  A022015000000096906  Male
# 2  A042015000000118649  Male
# 3  A062015000000167469  Male
# 4  A132015000000550479  Male
#
#                                              ADMTYPE OFFGENERAL EDUCATION  \
# 0                               New court commitment   Property         9
# 1  Other admission (including unsentenced, transf...      Drugs         9
# 2                               New court commitment    Violent         9
# 3                           Parole return/revocation   Property         9
# 4                               New court commitment    Violent         9
#
#   ADMITYR RELEASEYR  MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR  \
# 0    2006      2010                NaN                NaN           NaN
# 1    2008      2008                NaN                NaN           NaN
# 2    2013      2014             2014.0             2014.0           NaN
# 3    1996      1996                NaN                NaN           NaN
# 4    1968      1972             1978.0                NaN           NaN
#
#         SENTLGTH                                          OFFDETAIL  \
# 0  10-24.9 years                                              Fraud
# 1       < 1 year  Drugs (includes possession, distribution, traf...
# 2       < 1 year                             Other violent offenses
# 3    2-4.9 years                                           Burglary
# 4    5-9.9 years                                            Robbery
#
#                   RACE     AGEADMIT   AGERELEASE     TIMESRVD  \
# 0              Missing  35-44 years  35-44 years  2-4.9 years
# 1  White, non-Hispanic  35-44 years  35-44 years     < 1 year
# 2  White, non-Hispanic  18-24 years  18-24 years     < 1 year
# 3  White, non-Hispanic  25-34 years  25-34 years     < 1 year
# 4  White, non-Hispanic  18-24 years  18-24 years  2-4.9 years
#
#                                              RELTYPE       STATE
# 0  Other release (including death, transfer, AWOL...     Alabama
# 1                                                NaN      Alaska
# 2                                Conditional release     Arizona
# 3                                Conditional release  California
# 4                                Conditional release     Georgia

# %%
'''
File Name: Prison Admissions
Contents of Files:
The data file contains one record for each admission to prison. An individual person may have more than one record if s/he was admitted more than once.
File Dimensions:
• No. of Cases: 13,815,009 • No. of Variables: 14
• Record Length: 31
• Records per Case: 1
• Overall No. of Records: 13,815,009
'''
df2 = pd.read_stata('ICPSR_36404-V2/ICPSR_36404/DS0002/36404-0002-Data.dta')
df2.head()
# Out:
#       SEX  RPTYEAR    STATE         EDUCATION               ADMTYPE  \
# 0    Male     1991  Alabama    HS diploma/GED  New court commitment
# 1  Female     1991  Alabama   <HS diploma/GED  New court commitment
# 2    Male     1991  Alabama  Ungraded/unknown  New court commitment
# 3    Male     1991  Alabama    HS diploma/GED  New court commitment
# 4    Male     1991  Alabama   <HS diploma/GED  New court commitment
#
#      OFFGENERAL  MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR  ADMITYR  \
# 0      Property                NaN                NaN           NaN   1991.0
# 1      Property                NaN                NaN           NaN   1991.0
# 2         Drugs                NaN                NaN           NaN   1991.0
# 3  Public order                NaN                NaN           NaN   1991.0
# 4      Property                NaN                NaN           NaN   1991.0
#
#       SENTLGTH                                          OFFDETAIL  \
# 0  2-4.9 years                                           Burglary
# 1     < 1 year                                            Larceny
# 2  2-4.9 years  Drugs (includes possession, distribution, traf...
# 3  5-9.9 years                                       Public order
# 4  5-9.9 years                                            Larceny
#
#                   RACE     AGEADMIT
# 0  Black, non-Hispanic  18-24 years
# 1  Black, non-Hispanic  18-24 years
# 2  Black, non-Hispanic  25-34 years
# 3  White, non-Hispanic  18-24 years
# 4  Black, non-Hispanic  18-24 years

# %%
'''
File Name: Prison Releases
Contents of Files:
The data file contains one record for each release from prison. An individual person may have more than one record if s/he was released more than once.
File Dimensions:
• No. of Cases: 13,230,444 • No. of Variables: 18
• Record Length: 39
• Records per Case: 1
• Overall No. of Records: 13,230,444
'''

import pandas as pd

df3 = pd.read_stata('ICPSR_36404-V2/ICPSR_36404/DS0003/36404-0003-Data.dta')
df3.head()
# Out:
#     SEX  RPTYEAR    STATE       EDUCATION               ADMTYPE    OFFGENERAL  \
# 0  Male     1991  Alabama     Any college  New court commitment       Violent
# 1  Male     1991  Alabama  HS diploma/GED  New court commitment       Violent
# 2  Male     1991  Alabama  HS diploma/GED  New court commitment         Drugs
# 3  Male     1991  Alabama  HS diploma/GED  New court commitment      Property
# 4  Male     1991  Alabama     Any college  New court commitment  Public order
#
#    MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR ADMITYR       SENTLGTH  \
# 0                NaN                NaN           NaN    1983     >=25 years
# 1                NaN                NaN           NaN    1987  10-24.9 years
# 2                NaN                NaN           NaN    1987  10-24.9 years
# 3                NaN                NaN           NaN    1989  10-24.9 years
# 4                NaN                NaN           NaN    1989    5-9.9 years
#
#                                            OFFDETAIL                 RACE  \
# 0      Murder (including non-negligent manslaughter)  White, non-Hispanic
# 1                                            Robbery  White, non-Hispanic
# 2  Drugs (includes possession, distribution, traf...  White, non-Hispanic
# 3                                           Burglary  Black, non-Hispanic
# 4                                       Public order              Missing
#
#       AGEADMIT RELYR                                            RELTYPE  \
# 0  25-34 years  1991                                Conditional release
# 1  25-34 years  1991                              Unconditional release
# 2  45-54 years  1991  Other release (including death, transfer, AWOL...
# 3  35-44 years  1991                              Unconditional release
# 4  25-34 years  1991                              Unconditional release
#
#        AGERLSE TIMESRVD_REL
# 0  35-44 years  5-9.9 years
# 1  25-34 years  2-4.9 years
# 2  45-54 years  2-4.9 years
# 3  35-44 years  2-4.9 years
# 4  25-34 years  2-4.9 years

# %%
'''
File Name: Year-End Population
Contents of Files:
The data file contains one record for each prisoner in custody on December 31 of each year. An individual person may have more than one record if s/he stayed in prison longer than one year, or if the individual had one or more returns to prison for which s/he was in custody on December 31 in multiple years.
File Dimensions:
• No. of Cases: 18,561,093 • No. of Variables: 16
• Record Length: 33
• Records per Case: 1
• Overall No. of Records: 18,561,093
'''

import pandas as pd

df4 = pd.read_stata('ICPSR_36404-V2/ICPSR_36404/DS0004/36404-0004-Data.dta')
df4.head()
# Out:
#     SEX  RPTYEAR       STATE         EDUCATION               ADMTYPE  \
# 0  Male     1999  California  Ungraded/unknown  New court commitment
# 1  Male     1999  California  Ungraded/unknown  New court commitment
# 2  Male     1999  California  Ungraded/unknown  New court commitment
# 3  Male     1999  California  Ungraded/unknown  New court commitment
# 4  Male     1999  California  Ungraded/unknown  New court commitment
#
#   OFFGENERAL  MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR ADMITYR  \
# 0    Violent                NaN                NaN           NaN    1955
# 1    Violent                NaN                NaN           NaN    1955
# 2    Violent                NaN                NaN           NaN    1957
# 3    Violent                NaN                NaN           NaN    1957
# 4    Violent                NaN                NaN           NaN    1957
#
#                                         SENTLGTH  \
# 0  Life, LWOP, Life plus additional years, Death
# 1  Life, LWOP, Life plus additional years, Death
# 2  Life, LWOP, Life plus additional years, Death
# 3  Life, LWOP, Life plus additional years, Death
# 4  Life, LWOP, Life plus additional years, Death
#
#                                        OFFDETAIL                         RACE  \
# 0  Murder (including non-negligent manslaughter)          Black, non-Hispanic
# 1  Murder (including non-negligent manslaughter)  Other race(s), non-Hispanic
# 2                   Aggravated or simple assault          Black, non-Hispanic
# 3  Murder (including non-negligent manslaughter)          White, non-Hispanic
# 4  Murder (including non-negligent manslaughter)          White, non-Hispanic
#
#       AGEADMIT   AGEYREND TIMESRVD_YREND
# 0  18-24 years  55+ years     >=10 years
# 1  25-34 years  55+ years     >=10 years
# 2  18-24 years  55+ years     >=10 years
# 3  18-24 years  55+ years     >=10 years
# 4  25-34 years  55+ years     >=10 years

# %%
#count by year total number of elderly prisoners in mass

# %%
import matplotlib.pyplot as plt
import numpy
import pylab
import scipy
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score
import numpy as np
# %matplotlib inline

df2copy = df4.copy()
df2copy = df2copy.query('STATE == "Massachusetts"')
df2copy.head()
df2copy = df2copy.query('AGEADMIT == "55+ years"')
grouped = df2copy.groupby(['RPTYEAR'])
nameList = []
groupList = []
for name, group in grouped:
    nameList.append(name)
    groupList.append(group["RPTYEAR"].count())

print(nameList)
print(groupList)

x = nameList
y = groupList


plt.figure(figsize=(20,10), dpi = 120)    
plt.suptitle("Number of Elderly (55+) Prisoners in Mass by Year", fontsize=20)
plt.ylabel('Number of Prisoners', fontsize=16)


# plot the data itself
plt.scatter(nameList, groupList)
plt.xticks(np.arange(min(nameList), max(nameList)+1, 1.0))

# calc the trendline
z = numpy.polyfit(x, y, 1)
p = numpy.poly1d(z)
pylab.plot(x,p(x),"r--")
# the line equation:
print("y=%.6fx+(%.6f)"%(z[0],z[1]))


coefficient_of_dermination = r2_score(y, p(x))
print(coefficient_of_dermination)
# Out:
# [2010, 2011, 2012, 2013, 2014]
# [382, 396, 413, 423, 425]
# y=11.300000x+(-22327.800000)
# 0.939726229026

# %%
#count by year total number of elderly prisoners in country

df2copy = df4.copy()
df2copy.head()
df2copy = df2copy.query('AGEADMIT == "55+ years"')
grouped = df2copy.groupby(['RPTYEAR'])
nameList = []
groupList = []
for name, group in grouped:
    nameList.append(name)
    groupList.append(group["RPTYEAR"].count())

print(nameList)
print(groupList)

x = nameList
y = groupList

plt.figure(figsize=(20,10), dpi = 120)    
plt.suptitle("Number of Elderly (55+) Prisoners by Year", fontsize=20)
plt.ylabel('Number of Prisoners', fontsize=16)

# plot the data itself
plt.scatter(nameList, groupList)
plt.xticks(np.arange(min(nameList), max(nameList)+1, 1.0))

# calc the trendline
z = numpy.polyfit(x, y, 1)
p = numpy.poly1d(z)
pylab.plot(x,p(x),"r--")
# the line equation:
print("y=%.6fx+(%.6f)"%(z[0],z[1]))

coefficient_of_dermination = r2_score(y, p(x))
print(coefficient_of_dermination)
# Out:
# [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]
# [10755, 17497, 19332, 21687, 23027, 24646, 27209, 29682, 34319, 37738, 41389, 45022, 47340, 49809, 52376, 47151]
# y=2704.992647x+(-5394506.558824)
# 0.96926298643

# %%
#Number of conditional releases per year for elderly in Mass

# Organize data so we have only what we want (55+, only mass etc)
dfcopy = df3.copy()
dfcopy = dfcopy.query('AGERLSE == "55+ years"')
dfcopy = dfcopy.query('STATE == "Massachusetts"')


#dfcopy = dfcopy.loc[dfcopy['RELYR'] == 2014]
print("size of DF: ", len(dfcopy))


dfcopy.head()
# Out:
# size of DF:  1409
#          SEX  RPTYEAR          STATE         EDUCATION               ADMTYPE  \
# 529767  Male     1992  Massachusetts    HS diploma/GED  New court commitment
# 529855  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
# 530047  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
# 530250  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
# 530302  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
#
#           OFFGENERAL  MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR  \
# 529767         Drugs                NaN                NaN           NaN
# 529855  Public order                NaN                NaN           NaN
# 530047         Drugs                NaN                NaN           NaN
# 530250       Violent                NaN                NaN           NaN
# 530302       Violent                NaN                NaN           NaN
#
#        ADMITYR       SENTLGTH  \
# 529767    1987    5-9.9 years
# 529855    1988     >=25 years
# 530047    1989  10-24.9 years
# 530250    1990     >=25 years
# 530302    1991  10-24.9 years
#
#                                                 OFFDETAIL  \
# 529767  Drugs (includes possession, distribution, traf...
# 529855                                       Public order
# 530047  Drugs (includes possession, distribution, traf...
# 530250                                            Robbery
# 530302                                Rape/sexual assault
#
#                        RACE     AGEADMIT RELYR  \
# 529767  White, non-Hispanic  45-54 years  1992
# 529855   Hispanic, any race    55+ years  1992
# 530047  White, non-Hispanic    55+ years  1992
# 530250  White, non-Hispanic    55+ years  1992
# 530302  Black, non-Hispanic    55+ years  1992
#
#                                                   RELTYPE    AGERLSE  \
# 529767                                Conditional release  55+ years
# 529855                              Unconditional release  55+ years
# 530047                                Conditional release  55+ years
# 530250                                Conditional release  55+ years
# 530302  Other release (including death, transfer, AWOL...  55+ years
#
#        TIMESRVD_REL
# 529767  5-9.9 years
# 529855  2-4.9 years
# 530047  2-4.9 years
# 530250  1-1.9 years
# 530302     < 1 year

# %%
conditionalReleaseList = []
indexToDrop = []
indexCount = -1
#Iterate through our DF and construct a list called "conditionalReleaseList", which is either 1 or 0
for index, row in dfcopy.iterrows():
    indexCount = indexCount + 1
    if row["RELTYPE"] == "Conditional release":
        conditionalReleaseList.append(1)
    elif row["RELTYPE"] == "Unconditional release":
        conditionalReleaseList.append(0)
    else:
        indexToDrop.append(indexCount)


#Drop the indices we don't want to consider
dfcopy = dfcopy.drop(dfcopy.index[indexToDrop])


print("Size Check")
print("Size of DF: ", len(dfcopy))
print("Size of conditionalReleaseList: ", len(conditionalReleaseList) )
dfcopy["CONDITIONAL_RELEASE"] = conditionalReleaseList

total = len(dfcopy)
dfcopy.head()
# Out:
# Size Check
# Size of DF:  1186
# Size of conditionalReleaseList:  1186
#          SEX  RPTYEAR          STATE         EDUCATION               ADMTYPE  \
# 529767  Male     1992  Massachusetts    HS diploma/GED  New court commitment
# 529855  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
# 530047  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
# 530250  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
# 530312  Male     1992  Massachusetts  Ungraded/unknown  New court commitment
#
#           OFFGENERAL  MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR  \
# 529767         Drugs                NaN                NaN           NaN
# 529855  Public order                NaN                NaN           NaN
# 530047         Drugs                NaN                NaN           NaN
# 530250       Violent                NaN                NaN           NaN
# 530312       Violent                NaN                NaN           NaN
#
#        ADMITYR       SENTLGTH  \
# 529767    1987    5-9.9 years
# 529855    1988     >=25 years
# 530047    1989  10-24.9 years
# 530250    1990     >=25 years
# 530312    1991     >=25 years
#
#                                                 OFFDETAIL  \
# 529767  Drugs (includes possession, distribution, traf...
# 529855                                       Public order
# 530047  Drugs (includes possession, distribution, traf...
# 530250                                            Robbery
# 530312                                Rape/sexual assault
#
#                        RACE     AGEADMIT RELYR                RELTYPE  \
# 529767  White, non-Hispanic  45-54 years  1992    Conditional release
# 529855   Hispanic, any race    55+ years  1992  Unconditional release
# 530047  White, non-Hispanic    55+ years  1992    Conditional release
# 530250  White, non-Hispanic    55+ years  1992    Conditional release
# 530312  White, non-Hispanic  45-54 years  1992    Conditional release
#
#           AGERLSE TIMESRVD_REL  CONDITIONAL_RELEASE
# 529767  55+ years  5-9.9 years                    1
# 529855  55+ years  2-4.9 years                    0
# 530047  55+ years  2-4.9 years                    1
# 530250  55+ years  1-1.9 years                    1
# 530312  55+ years  1-1.9 years                    1

# %%
grouped = dfcopy.groupby(['RPTYEAR'])
nameList = []
groupList = []
for name, group in grouped:
    nameList.append(name)
    groupList.append(group["RPTYEAR"].count())

    
nameList = nameList[3:]
groupList = groupList[3:]

print(nameList)
print(groupList)

count = -1
for number in groupList:
    count = count + 1
    groupList[count] = number/total


print(groupList)

#plt.figure(figsize=(20,10), dpi = 120)
plt.bar(np.arange(5), groupList)
plt.xticks(np.arange(5), nameList)


plt.suptitle("Percentage of Conditional Releases per Year for Elderly (55+) in Mass by Year") #, fontsize=20
plt.xlabel('Year') #, fontsize=18
plt.ylabel('Percentage of Conditional Releases') #, fontsize=16
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
# Out:
# [2010, 2011, 2012, 2013, 2014]
# [180, 168, 197, 217, 203]
# [0.15177065767284992, 0.14165261382799327, 0.16610455311973019, 0.18296795952782463, 0.17116357504215851]
# [Text(0,0,'0%'),
#  Text(0,0,'2%'),
#  Text(0,0,'5%'),
#  Text(0,0,'8%'),
#  Text(0,0,'10%'),
#  Text(0,0,'12%'),
#  Text(0,0,'15%'),
#  Text(0,0,'18%'),
#  Text(0,0,'20%')]

# %% [markdown]
# # We don't use the below graphs because they are either incorrect or not necessary

# %%
#gets the number of prison admissions by year by race
import matplotlib.pyplot as plt
# %matplotlib inline

df2copy = df2.copy()
df2copy = df2copy.query('STATE == "Massachusetts"')
df2copy.head()
df2copy = df2copy.query('AGEADMIT == "55+ years"')
grouped = df2copy.groupby(['RPTYEAR', 'RACE'])
yeardict = {}
for name, group in grouped:
    print(name)
    if (name[0] not in yeardict):
        yeardict[name[0]] = []
    yeardict[name[0]].append([name[1], int(group[['SEX']].count().values)])
    print(int(group[['SEX']].count().values))
    #print((group.count()))

print(yeardict)

yearlist = []


counter = 0
whitelist = []
blacklist = []
hislist = []
mislist = []
otherlist = []
for key, value in yeardict.items():
    print (key)
    sum1 = 0
    otherbool = False
    misbool = False
    for item in value:
        sum1 += (item[1])
    #print(sum1)
    yearlist.append(key)
    for item in value:
        if item[0] == 'White, non-Hispanic':
            whitelist.append(item[1])
        elif item[0] == 'Black, non-Hispanic':
            blacklist.append(item[1])
        elif item[0] == 'Hispanic, any race':
            hislist.append(item[1])
        elif item[0] == 'Missing':
            mislist.append(item[1])
            misbool = True
        elif item[0] == 'Other race(s), non-Hispanic':
            otherlist.append(item[1])
            otherbool = True
        
        print("% of inmates with race " + item[0] + " = %.2f" % (item[1]/sum1))
    counter+=1
    if otherbool == False:
        otherlist.append(0)
    if misbool == False:
        mislist.append(0)
print(yearlist)

print(whitelist)
print(blacklist)
print(hislist)
print(mislist)
print(otherlist)


p1 = plt.bar(yearlist, whitelist, color='r')
p2 = plt.bar(yearlist, blacklist, bottom=whitelist, color='b')
p3 = plt.bar(yearlist, hislist, bottom=whitelist, color= 'g')
p4 = plt.bar(yearlist, mislist, bottom=whitelist, color= 'm')
p5 = plt.bar(yearlist, otherlist, bottom=whitelist, color='y')

plt.show()
# Out:
# (1992, 'White, non-Hispanic')
# 58
# (1992, 'Black, non-Hispanic')
# 9
# (1992, 'Hispanic, any race')
# 4
# (1992, 'Missing')
# 1
# (1993, 'White, non-Hispanic')
# 55
# (1993, 'Black, non-Hispanic')
# 7
# (1993, 'Hispanic, any race')
# 11
# (1993, 'Missing')
# 2
# (1994, 'White, non-Hispanic')
# 56
# (1994, 'Black, non-Hispanic')
# 10
# (1994, 'Hispanic, any race')
# 4
# (1994, 'Other race(s), non-Hispanic')
# 1
# (1994, 'Missing')
# 6
# (1995, 'White, non-Hispanic')
# 43
# (1995, 'Black, non-Hispanic')
# 5
# (1995, 'Hispanic, any race')
# 5
# (2010, 'White, non-Hispanic')
# 79
# (2010, 'Black, non-Hispanic')
# 14
# (2010, 'Hispanic, any race')
# 13
# (2010, 'Other race(s), non-Hispanic')
# 3
# (2010, 'Missing')
# 14
# (2011, 'White, non-Hispanic')
# 74
# (2011, 'Black, non-Hispanic')
# 25
# (2011, 'Hispanic, any race')
# 20
# (2011, 'Other race(s), non-Hispanic')
# 2
# (2011, 'Missing')
# 20
# (2012, 'White, non-Hispanic')
# 96
# (2012, 'Black, non-Hispanic')
# 25
# (2012, 'Hispanic, any race')
# 16
# (2012, 'Other race(s), non-Hispanic')
# 4
# (2012, 'Missing')
# 21
# (2013, 'White, non-Hispanic')
# 95
# (2013, 'Black, non-Hispanic')
# 30
# (2013, 'Hispanic, any race')
# 19
# (2013, 'Other race(s), non-Hispanic')
# 3
# (2013, 'Missing')
# 8
# (2014, 'White, non-Hispanic')
# 86
# (2014, 'Black, non-Hispanic')
# 30
# (2014, 'Hispanic, any race')
# 20
# (2014, 'Missing')
# 12
# {1992: [['White, non-Hispanic', 58], ['Black, non-Hispanic', 9], ['Hispanic, any race', 4], ['Missing', 1]], 1993: [['White, non-Hispanic', 55], ['Black, non-Hispanic', 7], ['Hispanic, any race', 11], ['Missing', 2]], 1994: [['White, non-Hispanic', 56], ['Black, non-Hispanic', 10], ['Hispanic, any race', 4], ['Other race(s), non-Hispanic', 1], ['Missing', 6]], 1995: [['White, non-Hispanic', 43], ['Black, non-Hispanic', 5], ['Hispanic, any race', 5]], 2010: [['White, non-Hispanic', 79], ['Black, non-Hispanic', 14], ['Hispanic, any race', 13], ['Other race(s), non-Hispanic', 3], ['Missing', 14]], 2011: [['White, non-Hispanic', 74], ['Black, non-Hispanic', 25], ['Hispanic, any race', 20], ['Other race(s), non-Hispanic', 2], ['Missing', 20]], 2012: [['White, non-Hispanic', 96], ['Black, non-Hispanic', 25], ['Hispanic, any race', 16], ['Other race(s), non-Hispanic', 4], ['Missing', 21]], 2013: [['White, non-Hispanic', 95], ['Black, non-Hispanic', 30], ['Hispanic, any race', 19], ['Other race(s), non-Hispanic', 3], ['Missing', 8]], 2014: [['White, non-Hispanic', 86], ['Black, non-Hispanic', 30], ['Hispanic, any race', 20], ['Missing', 12]]}
# 1992
# % of inmates with race White, non-Hispanic = 0.81
# % of inmates with race Black, non-Hispanic = 0.12
# % of inmates with race Hispanic, any race = 0.06
# % of inmates with race Missing = 0.01
# 1993
# % of inmates with race White, non-Hispanic = 0.73
# % of inmates with race Black, non-Hispanic = 0.09
# % of inmates with race Hispanic, any race = 0.15
# % of inmates with race Missing = 0.03
# 1994
# % of inmates with race White, non-Hispanic = 0.73
# % of inmates with race Black, non-Hispanic = 0.13
# % of inmates with race Hispanic, any race = 0.05
# % of inmates with race Other race(s), non-Hispanic = 0.01
# % of inmates with race Missing = 0.08
# 1995
# % of inmates with race White, non-Hispanic = 0.81
# % of inmates with race Black, non-Hispanic = 0.09
# % of inmates with race Hispanic, any race = 0.09
# 2010
# % of inmates with race White, non-Hispanic = 0.64
# % of inmates with race Black, non-Hispanic = 0.11
# % of inmates with race Hispanic, any race = 0.11
# % of inmates with race Other race(s), non-Hispanic = 0.02
# % of inmates with race Missing = 0.11
# 2011
# % of inmates with race White, non-Hispanic = 0.52
# % of inmates with race Black, non-Hispanic = 0.18
# % of inmates with race Hispanic, any race = 0.14
# % of inmates with race Other race(s), non-Hispanic = 0.01
# % of inmates with race Missing = 0.14
# 2012
# % of inmates with race White, non-Hispanic = 0.59
# % of inmates with race Black, non-Hispanic = 0.15
# % of inmates with race Hispanic, any race = 0.10
# % of inmates with race Other race(s), non-Hispanic = 0.02
# % of inmates with race Missing = 0.13
# 2013
# % of inmates with race White, non-Hispanic = 0.61
# % of inmates with race Black, non-Hispanic = 0.19
# % of inmates with race Hispanic, any race = 0.12
# % of inmates with race Other race(s), non-Hispanic = 0.02
# % of inmates with race Missing = 0.05
# 2014
# % of inmates with race White, non-Hispanic = 0.58
# % of inmates with race Black, non-Hispanic = 0.20
# % of inmates with race Hispanic, any race = 0.14
# % of inmates with race Missing = 0.08
# [1992, 1993, 1994, 1995, 2010, 2011, 2012, 2013, 2014]
# [58, 55, 56, 43, 79, 74, 96, 95, 86]
# [9, 7, 10, 5, 14, 25, 25, 30, 30]
# [4, 11, 4, 5, 13, 20, 16, 19, 20]
# [1, 2, 6, 0, 14, 20, 21, 8, 12]
# [0, 0, 1, 0, 3, 2, 4, 3, 0]

# %%
import matplotlib.patches as mpatches
#gets percentage by race by year
yearlist = []

counter = 0
whitelist = []
blacklist = []
hislist = []
mislist = []
otherlist = []
for key, value in yeardict.items():
    print (key)
    sum1 = 0
    otherbool = False
    misbool = False
    for item in value:
        sum1 += (item[1])
    #print(sum1)
    yearlist.append(key)
    for item in value:
        if item[0] == 'White, non-Hispanic':
            whitelist.append(item[1]/sum1)
        elif item[0] == 'Black, non-Hispanic':
            blacklist.append(item[1]/sum1)
        elif item[0] == 'Hispanic, any race':
            hislist.append(item[1]/sum1)
        elif item[0] == 'Missing':
            mislist.append(item[1]/sum1)
            misbool = True
        elif item[0] == 'Other race(s), non-Hispanic':
            otherlist.append(item[1]/sum1)
            otherbool = True
        
        print("% of inmates with race " + item[0] + " = %.2f" % (item[1]/sum1))
    counter+=1
    if otherbool == False:
        otherlist.append(0)
    if misbool == False:
        mislist.append(0)
print(yearlist)

print(whitelist)
print(blacklist)
print(hislist)
print(mislist)
print(otherlist)


plt.figure(figsize=(20,10), dpi = 120)    
plt.suptitle("Distribution of Race among Elderly (55+) Prisoners", fontsize=20)
plt.ylabel('Percentage of Prisoners of a Race', fontsize=16)
plt.xticks(np.arange(min(yearlist), max(yearlist)+1, 1.0))

r_patch = mpatches.Patch(color='r', label='White, non-Hispanic')
b_patch = mpatches.Patch(color='b', label='Black, non-Hispanic')
g_patch = mpatches.Patch(color='g', label='Hispanic, any race')
m_patch = mpatches.Patch(color='m', label='Missing')
y_patch = mpatches.Patch(color='y', label='Other race(s), non-Hispanic')
plt.legend(handles=[r_patch,b_patch,g_patch,m_patch,y_patch], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., handlelength=5, borderpad=1.2, labelspacing=1.2)

plt.plot(yearlist, whitelist, c='r')
plt.plot(yearlist, blacklist, c='b')
plt.plot(yearlist, hislist, c='g')
plt.plot(yearlist, mislist, c='m')
plt.plot(yearlist, otherlist, c='y')


plt.show()
# Out:
# 1992
# % of inmates with race White, non-Hispanic = 0.81
# % of inmates with race Black, non-Hispanic = 0.12
# % of inmates with race Hispanic, any race = 0.06
# % of inmates with race Missing = 0.01
# 1993
# % of inmates with race White, non-Hispanic = 0.73
# % of inmates with race Black, non-Hispanic = 0.09
# % of inmates with race Hispanic, any race = 0.15
# % of inmates with race Missing = 0.03
# 1994
# % of inmates with race White, non-Hispanic = 0.73
# % of inmates with race Black, non-Hispanic = 0.13
# % of inmates with race Hispanic, any race = 0.05
# % of inmates with race Other race(s), non-Hispanic = 0.01
# % of inmates with race Missing = 0.08
# 1995
# % of inmates with race White, non-Hispanic = 0.81
# % of inmates with race Black, non-Hispanic = 0.09
# % of inmates with race Hispanic, any race = 0.09
# 2010
# % of inmates with race White, non-Hispanic = 0.64
# % of inmates with race Black, non-Hispanic = 0.11
# % of inmates with race Hispanic, any race = 0.11
# % of inmates with race Other race(s), non-Hispanic = 0.02
# % of inmates with race Missing = 0.11
# 2011
# % of inmates with race White, non-Hispanic = 0.52
# % of inmates with race Black, non-Hispanic = 0.18
# % of inmates with race Hispanic, any race = 0.14
# % of inmates with race Other race(s), non-Hispanic = 0.01
# % of inmates with race Missing = 0.14
# 2012
# % of inmates with race White, non-Hispanic = 0.59
# % of inmates with race Black, non-Hispanic = 0.15
# % of inmates with race Hispanic, any race = 0.10
# % of inmates with race Other race(s), non-Hispanic = 0.02
# % of inmates with race Missing = 0.13
# 2013
# % of inmates with race White, non-Hispanic = 0.61
# % of inmates with race Black, non-Hispanic = 0.19
# % of inmates with race Hispanic, any race = 0.12
# % of inmates with race Other race(s), non-Hispanic = 0.02
# % of inmates with race Missing = 0.05
# 2014
# % of inmates with race White, non-Hispanic = 0.58
# % of inmates with race Black, non-Hispanic = 0.20
# % of inmates with race Hispanic, any race = 0.14
# % of inmates with race Missing = 0.08
# [1992, 1993, 1994, 1995, 2010, 2011, 2012, 2013, 2014]
# [0.8055555555555556, 0.7333333333333333, 0.7272727272727273, 0.8113207547169812, 0.6422764227642277, 0.524822695035461, 0.5925925925925926, 0.6129032258064516, 0.581081081081081]
# [0.125, 0.09333333333333334, 0.12987012987012986, 0.09433962264150944, 0.11382113821138211, 0.1773049645390071, 0.15432098765432098, 0.1935483870967742, 0.20270270270270271]
# [0.05555555555555555, 0.14666666666666667, 0.05194805194805195, 0.09433962264150944, 0.10569105691056911, 0.14184397163120568, 0.09876543209876543, 0.12258064516129032, 0.13513513513513514]
# [0.013888888888888888, 0.02666666666666667, 0.07792207792207792, 0, 0.11382113821138211, 0.14184397163120568, 0.12962962962962962, 0.05161290322580645, 0.08108108108108109]
# [0, 0, 0.012987012987012988, 0, 0.024390243902439025, 0.014184397163120567, 0.024691358024691357, 0.01935483870967742, 0]

# %% [markdown]
# compare the percentage of people of race/minorites that get admitted and compare to overall minority population of the
# state we can find out if certain races are more likely to be admitted in prison while they are older.
#
# find census data. 1% will go to jail. of the percentage that go to jail, we can find which race of people get re-admitted
# to jail and thus
#
# percentage of people getting re-admitted to prision will be overrepresented compared to state census.

# %%
'''
Graph of how many inmates increase being 55+ compared to the nation over 16 years
'''

dfyears = df4.copy()
#query for only those who are 55+ in a given year in prison
dfyears = dfyears.query('AGEYREND == "55+ years"')
#The year the data was taken
grouped = dfyears.groupby(['RPTYEAR'])
countdf = grouped.count()
countdf
# Out:
#             SEX   STATE  EDUCATION  ADMTYPE  OFFGENERAL  MAND_PRISREL_YEAR  \
# RPTYEAR
# 1999      23373   23373      23373    23373       23373                  0
# 2000      36826   36826      36826    36826       36826              15770
# 2001      41741   41741      41741    41741       41741              14556
# 2002      48362   48362      48362    48362       48362              18226
# 2003      50047   50047      50047    50047       50047              27118
# 2004      54430   54430      54430    54430       54430              29187
# 2005      60236   60236      60236    60236       60236              28822
# 2006      66260   66260      66260    66260       66260              32261
# 2007      77450   77450      77450    77450       77450              36091
# 2008      85320   85320      85320    85320       85320              40278
# 2009      94748   94748      94748    94748       94748              45584
# 2010     104854  104854     104854   104854      104854              52296
# 2011     112532  112532     112532   112532      112532              58358
# 2012     120368  120368     120368   120368      120368              64057
# 2013     126709  126709     126709   126709      126709              66147
# 2014     113777  113777     113777   113777      113777              67035
#
#          PROJ_PRISREL_YEAR  PARELIG_YEAR  ADMITYR  SENTLGTH  OFFDETAIL  \
# RPTYEAR
# 1999                     0             0    23373     23373      23373
# 2000                 17177         11254    36826     36826      36826
# 2001                 16474         13271    41741     41741      41741
# 2002                 20220         15980    48362     48362      48362
# 2003                 22470         23274    50047     50047      50047
# 2004                 24775         25181    54430     54430      54430
# 2005                 35082         27683    60236     60236      60236
# 2006                 39524         31015    66260     66260      66260
# 2007                 47236         33640    77450     77450      77450
# 2008                 52660         36425    85320     85320      85320
# 2009                 59805         39837    94748     94748      94748
# 2010                 66589         44115   104854    104854     104854
# 2011                 72011         47283   112532    112532     112532
# 2012                 77427         49974   120368    120368     120368
# 2013                 83246         52184   126709    126709     126709
# 2014                 76134         50241   113777    113777     113777
#
#            RACE  AGEADMIT  AGEYREND  TIMESRVD_YREND
# RPTYEAR
# 1999      23373     23373     23373           23373
# 2000      36826     36826     36826           36826
# 2001      41741     41741     41741           41741
# 2002      48362     48362     48362           48362
# 2003      50047     50047     50047           50047
# 2004      54430     54430     54430           54430
# 2005      60236     60236     60236           60236
# 2006      66260     66260     66260           66260
# 2007      77450     77450     77450           77450
# 2008      85320     85320     85320           85320
# 2009      94748     94748     94748           94748
# 2010     104854    104854    104854          104854
# 2011     112532    112532    112532          112532
# 2012     120368    120368    120368          120368
# 2013     126709    126709    126709          126709
# 2014     113777    113777    113777          113777

# %%
#To graph this, just use sex as number of inmates; every inmate has a sex value.
vector = []
for index, row in countdf.iterrows():
    vector.append(row["SEX"])
    
print(vector)
# Out:
# [23373, 36826, 41741, 48362, 50047, 54430, 60236, 66260, 77450, 85320, 94748, 104854, 112532, 120368, 126709, 113777]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

years = [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]

plt.figure(figsize=(20,10), dpi = 120)
plt.bar(years, vector)
plt.xticks(np.arange(min(years), max(years)+1, 1.0))
plt.suptitle("Inmates who are 55+ and in Prison by Year, in the US", fontsize=20)
plt.xlabel('Year', fontsize=18)
plt.ylabel('Number of Prisoners', fontsize=16)
# Out:
# Text(0,0.5,'Number of Prisoners')
